# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv",header = None)
# Out:
#               0         1       2             3   \
# 0    PassengerId  Survived  Pclass         Lname
# 1              1         0       3        Braund
# 2              2         1       1       Cumings
# 3              3         1       3     Heikkinen
# 4              4         1       1      Futrelle
# ..           ...       ...     ...           ...
# 152          152         1       1         Pears
# 153          153         0       3           Meo
# 154          154         0       3  van Billiard
# 155          155         0       3         Olsen
# 156          156         0       1      Williams
#
#                                               4       5     6      7      8   \
# 0                                           Name     Sex   Age  SibSp  Parch
# 1                                Mr. Owen Harris    male    22      1      0
# 2     Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0
# ...

# %%
names = ["PassengerId","Survived","Pclass","Lname","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"]
pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv",names =names , index_col = "Name")
# Out:
#                                              PassengerId  Survived  Pclass  \
# Name
# Name                                         PassengerId  Survived  Pclass
#  Mr. Owen Harris                                       1         0       3
#  Mrs. John Bradley (Florence Briggs Thayer)            2         1       1
#  Miss. Laina                                           3         1       3
#  Mrs. Jacques Heath (Lily May Peel)                    4         1       1
# ...                                                  ...       ...     ...
#  Mrs. Thomas (Edith Wearne)                          152         1       1
#  Mr. Alfonzo                                         153         0       3
#  Mr. Austin Blyler                                   154         0       3
#  Mr. Ole Martin                                      155         0       3
#  Mr. Charles Duane                                   156         0       1
#
# ...

# %%
df2 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , index_col = ["Name","Ticket"])
df2
# Out:
#                                                               PassengerId  \
# Name                                        Ticket
#  Mr. Owen Harris                            A/5 21171                   1
#  Mrs. John Bradley (Florence Briggs Thayer) PC 17599                    2
#  Miss. Laina                                STON/O2. 3101282            3
#  Mrs. Jacques Heath (Lily May Peel)         113803                      4
#  Mr. William Henry                          373450                      5
# ...                                                                   ...
#  Mrs. Thomas (Edith Wearne)                 113776                    152
#  Mr. Alfonzo                                A.5. 11206                153
#  Mr. Austin Blyler                          A/5. 851                  154
#  Mr. Ole Martin                             Fa 265302                 155
#  Mr. Charles Duane                          PC 17597                  156
#
# ...

# %% [markdown]
# df3 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv", sep = "\s+")
# df3

# %%
It seems like there might be an issue with your code. The pd.read_csv function is typically used for reading comma-separated values (CSV) files, and the sep parameter is used to specify the delimiter. In your case, you've set sep to "\s+", which indicates whitespace as the delimiter.

If your Titanic dataset is a CSV file, you should set sep to the appropriate delimiter, usually a comma. Here's an example assuming your file is a CSV:

python
Copy code
import pandas as pd

# Replace 'your_file_path' with the actual path to your Titanic CSV file
file_path = "C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv"

# Assuming it's a CSV file with a comma as the delimiter
df3 = pd.read_csv(file_path)

# Display the DataFrame
print(df3)
If your file is not a CSV and has a different format or delimiter, you should adjust the sep parameter accordingly. If you encounter any issues or have more details about the file format, feel free to provide additional information so I can assist you better.

# %%
pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , skiprows=[0,1])
# Out:
#        2  1  1.1       Cumings  Mrs. John Bradley (Florence Briggs Thayer)  \
# 0      3  1    3     Heikkinen                                 Miss. Laina
# 1      4  1    1      Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 2      5  0    3         Allen                           Mr. William Henry
# 3      6  0    3         Moran                                   Mr. James
# 4      7  0    1      McCarthy                               Mr. Timothy J
# ..   ... ..  ...           ...                                         ...
# 149  152  1    1         Pears                  Mrs. Thomas (Edith Wearne)
# 150  153  0    3           Meo                                 Mr. Alfonzo
# 151  154  0    3  van Billiard                           Mr. Austin Blyler
# 152  155  0    3         Olsen                              Mr. Ole Martin
# 153  156  0    1      Williams                           Mr. Charles Duane
#
#      female    38  1.2  0          PC 17599  71.2833   C85  C
# ...

# %%
df6 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" )
pd.isna(df6)
# Out:
#      PassengerId  Survived  Pclass  Lname   Name    Sex    Age  SibSp  Parch  \
# 0          False     False   False  False  False  False  False  False  False
# 1          False     False   False  False  False  False  False  False  False
# 2          False     False   False  False  False  False  False  False  False
# 3          False     False   False  False  False  False  False  False  False
# 4          False     False   False  False  False  False  False  False  False
# ..           ...       ...     ...    ...    ...    ...    ...    ...    ...
# 151        False     False   False  False  False  False  False  False  False
# 152        False     False   False  False  False  False  False  False  False
# 153        False     False   False  False  False  False  False  False  False
# 154        False     False   False  False  False  False   True  False  False
# 155        False     False   False  False  False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# ...

# %%
df9 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , na_values = ["NULL"])
df9
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
df10 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , keep_default_na = False)
df10
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male    22      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0
# 2                                    Miss. Laina  female    26      0      0
# ...

# %%
df10.isna()
# Out:
#      PassengerId  Survived  Pclass  Lname   Name    Sex    Age  SibSp  Parch  \
# 0          False     False   False  False  False  False  False  False  False
# 1          False     False   False  False  False  False  False  False  False
# 2          False     False   False  False  False  False  False  False  False
# 3          False     False   False  False  False  False  False  False  False
# 4          False     False   False  False  False  False  False  False  False
# ..           ...       ...     ...    ...    ...    ...    ...    ...    ...
# 151        False     False   False  False  False  False  False  False  False
# 152        False     False   False  False  False  False  False  False  False
# 153        False     False   False  False  False  False  False  False  False
# 154        False     False   False  False  False  False  False  False  False
# 155        False     False   False  False  False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# ...

# %%
df11 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , keep_default_na = False, na_values= ["NA"])
df11
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male    22      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0
# 2                                    Miss. Laina  female    26      0      0
# ...

# %%
df11.isna()
# Out:
#      PassengerId  Survived  Pclass  Lname   Name    Sex    Age  SibSp  Parch  \
# 0          False     False   False  False  False  False  False  False  False
# 1          False     False   False  False  False  False  False  False  False
# 2          False     False   False  False  False  False  False  False  False
# 3          False     False   False  False  False  False  False  False  False
# 4          False     False   False  False  False  False  False  False  False
# ..           ...       ...     ...    ...    ...    ...    ...    ...    ...
# 151        False     False   False  False  False  False  False  False  False
# 152        False     False   False  False  False  False  False  False  False
# 153        False     False   False  False  False  False  False  False  False
# 154        False     False   False  False  False  False  False  False  False
# 155        False     False   False  False  False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# ...

# %%
Random = {"XYZ1":["abc","efg"],"klm" : ["dickhead","head dick"]}
df12 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , na_values = Random , keep_default_na = False)
df12
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male    22      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0
# 2                                    Miss. Laina  female    26      0      0
# ...

# %%
pd.options.display.max_rows =6

# %%
df12
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# ..           ...       ...     ...           ...
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male    22      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0
# 2                                    Miss. Laina  female    26      0      0
# ..                                           ...     ...   ...    ...    ...
# 153                            Mr. Austin Blyler    male  40.5      0      2
# 154                               Mr. Ole Martin    male            0      0
# ...

# %%
df14 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , nrows = 5)
df14
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex  Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male   22      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female   38      1      0
# 2                                  Miss. Laina  female   26      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female   35      1      0
# 4                            Mr. William Henry    male   35      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
df15 = pd.read_csv("C:\\Users\\Sajid\\OneDrive\\Documents\\ce1dc0436aba5b7a5c9666f47fa5a380-5ce3854392b43ff97907112d344fc008229b0445\\titanic.csv" , chunksize = 1000)
df15

# %%
type(df15)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
tot = pd.Series(dtype = 'int64')
for piece in df15:
    tot = tot.add(piece["PassengerId"].value_counts(),fill_value = 0)
tot = tot.sort_values(ascending = False)

# %%
print(tot[:9])
# Out:
# Series([], dtype: int64)
